# %% [markdown]
# # Твиты
#
# 1) В качестве брокера сообщений использовать Kafka.
#
# 2) Для работы с потоком твитов - пакет tweepy под Python.

# %% [markdown]
# ## Подготовка

# %% [raw]
# python3 -m pip install kafka-python rapidjson tweepy

# %% [raw]
# sudo service kafka-server restart

# %% [raw]
# kafka-topics --create --zookeeper localhost:2181 --topic Tweets --partition 1 --replication-factor 1

# %% [raw]
# kafka-console-producer --broker-list localhost:9092 -topic Tweets

# %% [markdown]
# ## Задача 4. Подсчет количества твитов пользователей
#
# Напишите программу, которая подсчитывает количество твитов каждого пользователя в течение 1 мин. и в течение 10 мин. каждые 30 сек.
#
# Выведите результат в отсортированном по убыванию виде. В списке id пользователей заменить на их screen_name.
#
# Исходные данные:
# - id пользователей: "285532415", "147964447", "34200559", "338960856", "200036850", "72525490", "20510157", "99918629"

# %% [markdown]
# **tweets_producer.py**
#
# ```python
# # -*- coding: utf-8 -*-
# import logging
# import sys
#
# import rapidjson
# import tweepy
#
# from tweepy.streaming import json
# from kafka import KafkaProducer
#
# logger = logging.getLogger('tweets_producer')
# logger.setLevel(logging.INFO)
#
# handler = logging.StreamHandler(sys.stdout)
# handler.setFormatter(logging.Formatter('[%(levelname)s] %(asctime)s  %(name)s: %(message)s'))
# logger.addHandler(handler)
#
#
# KAFKA_SERVERS = ('localhost:9092',)
# TWEETS_KAFKA_TOPIC = 'Tweets'
#
# CONSUMER_TOKEN = '5o0JhYy18cIGWgpOGXX8iK2Ig'
# CONSUMER_SECRET = 'ie67wSeBT6ZxjLOuXD1ICXV7uE9gOjfUlK6TR7IrYZmfwG1DUF'
# ACCESS_TOKEN = '4196894355-B58LIK7zQF0Hb061cNcRRxAff6mQaC1EA2XL3Hb'
# ACCESS_SECRET = 'qcrG7SK1fVprCOgbT2dqbNCTMLkVuSwdmOE2XwcewT7OT'
#
# USERS_IDS = ('285532415', '147964447', '34200559', '338960856', '200036850', '72525490', '20510157', '99918629')
#
#
# class BaseListener(tweepy.StreamListener):
#
#     def __init__(self):
#         self.kafka_producer = KafkaProducer(bootstrap_servers=KAFKA_SERVERS)
#
#     def on_status(self, status):
#         logger.warning('Status: %s', status.text)
#
#     def on_error(self, status_code):
#         logger.warning(f'Error: %s', status_code)
#
#
# class TweetsStreamListener(BaseListener):
#
#     def on_data(self, raw_data):
#         data = rapidjson.loads(raw_data)
#
#         tid = data.get('id', None)
#         if not tid:
#             logger.warning('Tweet ID was not found in data: %s', raw_data)
#             return True
#
#         user = data.get('user', None)
#         if not user:
#             logger.warning('User was not found in data: %s', raw_data)
#             return True
#
#         screen_name, uid = user['screen_name'], user['id']
#
#         logger.info(
#             'Received 1 tweet from @%s[%s]. Send to Kafka topic `%s`',
#             screen_name, uid, TWEETS_KAFKA_TOPIC
#         )
#
#         self.kafka_producer.send(TWEETS_KAFKA_TOPIC,
#             rapidjson.dumps({
#                 'tid': tid,
#                 'screen_name': screen_name,
#             }).encode('utf-8')
#         )
#         return True
#
#
# def main():
#     auth = tweepy.OAuthHandler(CONSUMER_TOKEN, CONSUMER_SECRET)
#     auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
#
#     api = tweepy.API(auth)
#
#     tweets_stream = tweepy.Stream(auth=api.auth, listener=TweetsStreamListener())
#     logger.info('Start tweets receiving...')
#     tweets_stream.filter(follow=USERS_IDS)
#
#
# if __name__ == '__main__':
#     try:
#         main()
#     except KeyboardInterrupt:
#         logger.warning('Was stopped by user request')
#
# ```

# %% [raw]
# [cloudera@quickstart tweets_tasks]$ timeout 10m python3 tweets_producer.py > producer.out
# 2018-12-16 06:58:23,198 [INFO] tweets_producer: Start tweets receiving...
# 2018-12-16 06:58:26,898 [INFO] tweets_producer: Received 1 tweet from @SultanIskander[999348547802853378]
# 2018-12-16 06:58:29,764 [INFO] tweets_producer: Received 1 tweet from @mlTerNw9oVRhAl5[3134768049]
# 2018-12-16 06:58:33,962 [INFO] tweets_producer: Received 1 tweet from @a_weuve[4385767653]
# 2018-12-16 06:58:34,987 [INFO] tweets_producer: Received 1 tweet from @rentvchannel[200036850]
# 2018-12-16 06:58:35,909 [INFO] tweets_producer: Received 1 tweet from @_kmv_[161254913]
# 2018-12-16 06:58:52,534 [INFO] tweets_producer: Received 1 tweet from @proffmed[849698890173612032]
# 2018-12-16 06:58:52,907 [INFO] tweets_producer: Received 1 tweet from @KZ8JA4mRYTO78Uj[1071064400340140033]
# 2018-12-16 06:59:04,990 [INFO] tweets_producer: Received 1 tweet from @isv_yamal[319559770]
# 2018-12-16 06:59:08,692 [INFO] tweets_producer: Received 1 tweet from @nehueviy[2608064537]
# 2018-12-16 06:59:09,905 [INFO] tweets_producer: Received 1 tweet from @eduard_kenig[3069936065]
# 2018-12-16 06:59:16,050 [INFO] tweets_producer: Received 1 tweet from @Dmitriy0709[431928805]
# 2018-12-16 06:59:19,020 [INFO] tweets_producer: Received 1 tweet from @asLcqdxsZKLAjJD[913486584594526208]
# 2018-12-16 06:59:19,160 [INFO] tweets_producer: Received 1 tweet from @oZJnhO5zRr5Fg7c[960189338859524096]
# 2018-12-16 06:59:22,911 [INFO] tweets_producer: Received 1 tweet from @nehueviy[2608064537]
# 2018-12-16 06:59:32,741 [INFO] tweets_producer: Received 1 tweet from @Sirius_st[600877408]
# 2018-12-16 06:59:33,560 [INFO] tweets_producer: Received 1 tweet from @gziks1[2453589733]
# 2018-12-16 06:59:38,053 [INFO] tweets_producer: Received 1 tweet from @DNMotovilov[160825649]
# 2018-12-16 06:59:50,461 [INFO] tweets_producer: Received 1 tweet from @t_Wankan[337866358]
# 2018-12-16 06:59:53,119 [INFO] tweets_producer: Received 1 tweet from @GirafeMarius[2345572830]
# 2018-12-16 06:59:55,167 [INFO] tweets_producer: Received 1 tweet from @SultanIskander[999348547802853378]
# 2018-12-16 06:59:56,602 [INFO] tweets_producer: Received 1 tweet from @wou4ik[832819514]
# 2018-12-16 07:00:03,838 [INFO] tweets_producer: Received 1 tweet from @c1eHA9qsKhbG3Pn[780894728237813760]
# 2018-12-16 07:00:18,208 [INFO] tweets_producer: Received 1 tweet from @Evgenia6849[945572245736435712]
# 2018-12-16 07:00:21,805 [INFO] tweets_producer: Received 1 tweet from @astahov777[3422655676]
# 2018-12-16 07:00:39,099 [INFO] tweets_producer: Received 1 tweet from @oCaealqhhAJEfqk[920297591203614720]
# 2018-12-16 07:00:42,068 [INFO] tweets_producer: Received 1 tweet from @ygodinka[455687285]
# 2018-12-16 07:00:42,579 [INFO] tweets_producer: Received 1 tweet from @VLagunov[3793029256]
# 2018-12-16 07:00:51,386 [INFO] tweets_producer: Received 1 tweet from @KZ8JA4mRYTO78Uj[1071064400340140033]
# 2018-12-16 07:00:59,783 [INFO] tweets_producer: Received 1 tweet from @SultanIskander[999348547802853378]
# 2018-12-16 07:01:07,566 [INFO] tweets_producer: Received 1 tweet from @nehueviy[2608064537]
# 2018-12-16 07:01:13,932 [INFO] tweets_producer: Received 1 tweet from @doctortima[473824335]
# 2018-12-16 07:01:19,341 [INFO] tweets_producer: Received 1 tweet from @VasiliyRakovich[1340003623]
# 2018-12-16 07:01:20,811 [INFO] tweets_producer: Received 1 tweet from @nehueviy[2608064537]
# 2018-12-16 07:01:27,225 [INFO] tweets_producer: Received 1 tweet from @vesti_news[72525490]
# 2018-12-16 07:01:33,154 [INFO] tweets_producer: Received 1 tweet from @nehueviy[2608064537]
# 2018-12-16 07:01:45,351 [INFO] tweets_producer: Received 1 tweet from @pegass1[209599139]
# 2018-12-16 07:01:47,194 [INFO] tweets_producer: Received 1 tweet from @odesit741[2513730044]
# 2018-12-16 07:01:48,731 [INFO] tweets_producer: Received 1 tweet from @VStruncov[335556970]
# 2018-12-16 07:01:52,109 [INFO] tweets_producer: Received 1 tweet from @alexiKulik[881746967042437121]
# 2018-12-16 07:01:53,338 [INFO] tweets_producer: Received 1 tweet from @AMilena8891[453810289]
# 2018-12-16 07:02:11,862 [INFO] tweets_producer: Received 1 tweet from @pet19784[809167058193809412]
# 2018-12-16 07:02:14,821 [INFO] tweets_producer: Received 1 tweet from @VStruncov[335556970]
# 2018-12-16 07:02:18,940 [INFO] tweets_producer: Received 1 tweet from @AMilena8891[453810289]
# 2018-12-16 07:02:19,758 [INFO] tweets_producer: Received 1 tweet from @SO7fHpk6HBBgQUK[847890934532636672]
# 2018-12-16 07:02:22,371 [INFO] tweets_producer: Received 1 tweet from @13tucha1[1044183497274007552]
# 2018-12-16 07:02:28,958 [INFO] tweets_producer: Received 1 tweet from @Kag687WN3Wi6SHr[1067487689124036608]
# 2018-12-16 07:02:37,679 [INFO] tweets_producer: Received 1 tweet from @Honey_in_Blue[864849697]
# 2018-12-16 07:02:39,893 [INFO] tweets_producer: Received 1 tweet from @BulentKasapolu2[789003445151883264]
# 2018-12-16 07:02:49,864 [INFO] tweets_producer: Received 1 tweet from @uporotyisterh[901760510768513025]
# 2018-12-16 07:02:50,990 [INFO] tweets_producer: Received 1 tweet from @SultanIskander[999348547802853378]
# 2018-12-16 07:02:53,244 [INFO] tweets_producer: Received 1 tweet from @Tatyana_A2[1428397783]
# 2018-12-16 07:02:58,159 [INFO] tweets_producer: Received 1 tweet from @anatoliy156794[1644500486]
# 2018-12-16 07:02:59,798 [INFO] tweets_producer: Received 1 tweet from @Povar444[2731638775]
# 2018-12-16 07:03:04,406 [INFO] tweets_producer: Received 1 tweet from @PkJY2g8QyTGcH56[4522180155]
# 2018-12-16 07:03:08,626 [INFO] tweets_producer: Received 1 tweet from @YMGT373[202525308]
# 2018-12-16 07:03:15,362 [INFO] tweets_producer: Received 1 tweet from @AnnaAlchimie[2407401606]
# 2018-12-16 07:03:26,687 [INFO] tweets_producer: Received 1 tweet from @Anatoliy_A_Z[248814771]
# 2018-12-16 07:03:33,486 [INFO] tweets_producer: Received 1 tweet from @VStruncov[335556970]
# 2018-12-16 07:03:34,102 [INFO] tweets_producer: Received 1 tweet from @YMGT373[202525308]
# 2018-12-16 07:03:34,241 [INFO] tweets_producer: Received 1 tweet from @adgast[326215158]
# 2018-12-16 07:03:37,788 [INFO] tweets_producer: Received 1 tweet from @916_71[4768043788]
# 2018-12-16 07:03:40,863 [INFO] tweets_producer: Received 1 tweet from @tab2334[871393824022638592]
# 2018-12-16 07:03:50,383 [INFO] tweets_producer: Received 1 tweet from @sergey0905[556678873]
# 2018-12-16 07:04:05,129 [INFO] tweets_producer: Received 1 tweet from @DyakonovaLyubov[2805941172]
# 2018-12-16 07:04:06,870 [INFO] tweets_producer: Received 1 tweet from @slav_sh[2234010600]
# 2018-12-16 07:04:14,112 [INFO] tweets_producer: Received 1 tweet from @kryzhanskyi[1048092265749655552]
# 2018-12-16 07:04:15,253 [INFO] tweets_producer: Received 1 tweet from @Mr_AMV[613594903]
# 2018-12-16 07:04:19,159 [INFO] tweets_producer: Received 1 tweet from @YMGT373[202525308]
# 2018-12-16 07:04:20,081 [INFO] tweets_producer: Received 1 tweet from @denisvxbk[2172272679]
# 2018-12-16 07:04:23,152 [INFO] tweets_producer: Received 1 tweet from @ntvru[20510157]
# 2018-12-16 07:04:26,838 [INFO] tweets_producer: Received 1 tweet from @vesti_news[72525490]
# 2018-12-16 07:04:28,156 [INFO] tweets_producer: Received 1 tweet from @galla4512[2380306916]
# 2018-12-16 07:04:37,940 [INFO] tweets_producer: Received 1 tweet from @SEWEROKs[769216234428727301]
# 2018-12-16 07:04:47,625 [INFO] tweets_producer: Received 1 tweet from @pawelwah[308696812]
# 2018-12-16 07:04:47,799 [INFO] tweets_producer: Received 1 tweet from @Egorwolfen[4368733658]
# 2018-12-16 07:04:57,152 [INFO] tweets_producer: Received 1 tweet from @dmitrij7[239286126]
# 2018-12-16 07:05:01,552 [INFO] tweets_producer: Received 1 tweet from @GalSockolowa[1291010815]
# 2018-12-16 07:05:05,649 [INFO] tweets_producer: Received 1 tweet from @friendlybus[976911268996173824]
# 2018-12-16 07:05:07,901 [INFO] tweets_producer: Received 1 tweet from @SMI_TASS[163849347]
# 2018-12-16 07:05:09,028 [INFO] tweets_producer: Received 1 tweet from @kirasir61[712954817656827904]
# 2018-12-16 07:05:10,564 [INFO] tweets_producer: Received 1 tweet from @TikhonovVal[2859232621]
# 2018-12-16 07:05:12,717 [INFO] tweets_producer: Received 1 tweet from @13tucha1[1044183497274007552]
# 2018-12-16 07:05:15,684 [INFO] tweets_producer: Received 1 tweet from @fedyusha[1427698806]
# 2018-12-16 07:05:16,915 [INFO] tweets_producer: Received 1 tweet from @Gjhecmz[234559753]
# 2018-12-16 07:05:29,502 [INFO] tweets_producer: Received 1 tweet from @kryzhanskyi[1048092265749655552]
# 2018-12-16 07:05:35,447 [INFO] tweets_producer: Received 1 tweet from @Traveller_ru[235598808]
# 2018-12-16 07:05:36,840 [INFO] tweets_producer: Received 1 tweet from @Lebirdushka[4216729457]
# 2018-12-16 07:05:42,002 [INFO] tweets_producer: Received 1 tweet from @eqvival[18897243]
# 2018-12-16 07:05:44,415 [INFO] tweets_producer: Received 1 tweet from @goreshek[2223460326]
# 2018-12-16 07:05:49,988 [INFO] tweets_producer: Received 1 tweet from @kirasir61[712954817656827904]
# 2018-12-16 07:05:52,447 [INFO] tweets_producer: Received 1 tweet from @ramil_b_80[392163668]
# 2018-12-16 07:06:17,227 [INFO] tweets_producer: Received 1 tweet from @SultanIskander[999348547802853378]
# 2018-12-16 07:06:17,740 [INFO] tweets_producer: Received 1 tweet from @Sasha_Zatonsky[4336596497]
# 2018-12-16 07:06:19,787 [INFO] tweets_producer: Received 1 tweet from @UkrSlavemarket[2863316866]
# 2018-12-16 07:06:23,782 [INFO] tweets_producer: Received 1 tweet from @ProstoNatasha77[939073283391197184]
# 2018-12-16 07:06:28,800 [INFO] tweets_producer: Received 1 tweet from @Szaj4enko[804371390]
# 2018-12-16 07:06:28,840 [INFO] tweets_producer: Received 1 tweet from @NekuHatsumi[4804521195]
# 2018-12-16 07:06:29,822 [INFO] tweets_producer: Received 1 tweet from @kryzhanskyi[1048092265749655552]
# 2018-12-16 07:06:31,154 [INFO] tweets_producer: Received 1 tweet from @VLagunov[3793029256]
# 2018-12-16 07:06:34,431 [INFO] tweets_producer: Received 1 tweet from @47Angelina[529272874]
# 2018-12-16 07:06:36,069 [INFO] tweets_producer: Received 1 tweet from @interfax_news[147964447]
# 2018-12-16 07:06:36,580 [INFO] tweets_producer: Received 1 tweet from @SEWEROKs[769216234428727301]
# 2018-12-16 07:06:38,527 [INFO] tweets_producer: Received 1 tweet from @PkJY2g8QyTGcH56[4522180155]
# 2018-12-16 07:06:40,369 [INFO] tweets_producer: Received 1 tweet from @ntvru[20510157]
# 2018-12-16 07:06:48,462 [INFO] tweets_producer: Received 1 tweet from @gotovceva[297495126]
# 2018-12-16 07:06:48,613 [INFO] tweets_producer: Received 1 tweet from @goreshek[2223460326]
# 2018-12-16 07:06:50,713 [INFO] tweets_producer: Received 1 tweet from @8127682[128171724]
# 2018-12-16 07:06:59,507 [INFO] tweets_producer: Received 1 tweet from @SultanIskander[999348547802853378]
# 2018-12-16 07:07:04,966 [INFO] tweets_producer: Received 1 tweet from @1BMlo42WfteoBF7[4475353588]
# 2018-12-16 07:07:06,995 [INFO] tweets_producer: Received 1 tweet from @eqvival[18897243]
# 2018-12-16 07:07:07,510 [INFO] tweets_producer: Received 1 tweet from @SantaNikol[2841494559]
# 2018-12-16 07:07:08,105 [INFO] tweets_producer: Received 1 tweet from @zharaleksan[975067570092085248]
# 2018-12-16 07:07:15,903 [INFO] tweets_producer: Received 1 tweet from @VLagunov[3793029256]
# 2018-12-16 07:07:23,379 [INFO] tweets_producer: Received 1 tweet from @Eleech38[3715955183]
# 2018-12-16 07:07:24,300 [INFO] tweets_producer: Received 1 tweet from @kozenna[550482006]
# 2018-12-16 07:07:32,595 [INFO] tweets_producer: Received 1 tweet from @RuslanLutcenko[1854689647]
# 2018-12-16 07:07:34,604 [INFO] tweets_producer: Received 1 tweet from @46Ieliena[1249807088]
# 2018-12-16 07:07:41,827 [INFO] tweets_producer: Received 1 tweet from @climanseur[858335115000381441]
# 2018-12-16 07:07:46,318 [INFO] tweets_producer: Received 1 tweet from @goreshek[2223460326]
# 2018-12-16 07:07:52,666 [INFO] tweets_producer: Received 1 tweet from @VOROBEEY[158793000]

# %% [markdown]
# **tweets_counter_per_timeunit.py**
#
# ```python
# # -*- coding: utf-8 -*-
# import sys
#
# import rapidjson
#
# from pyspark import SparkContext
# from pyspark.streaming import StreamingContext
# from pyspark.streaming.kafka import KafkaUtils
#
# ZOOKEEPER_SERVER = 'localhost:2181'
# KAFKA_TOPIC = 'Tweets'
#
# APP_NAME = 'UsersTweetsCounter'
# BATCH_DURATION_SEC = 30
#
# MINUTE = 60
# TEN_MINUTES = MINUTE * 10
#
# # Init streaming
# spark_context = SparkContext(appName=APP_NAME)
# spark_context.setLogLevel('ERROR')
#
# streaming_context = StreamingContext(spark_context, BATCH_DURATION_SEC)
# streaming_context.checkpoint(f'{APP_NAME}__checkpoint')
#
# # Process tweets
# kafka_stream = KafkaUtils.createStream(
# 	streaming_context,
# 	ZOOKEEPER_SERVER,
# 	f'{APP_NAME}__consumers_group',
# 	{KAFKA_TOPIC: 1},
# )
#
# def ssum(a, b):
# 	return a + b
#
# # [
# #	(None, '{"tid":1074310692235292672,"screen_name":"Odev110"}'),
# #	(None, '{"tid":1074310709134139392,"screen_name":"kirillica1957"}')
# #	(None, '{"tid":1074310692235292673,"screen_name":"Odev110"}')
# # ] => [
# #	'Odev110',
# # 	'kirillica1957',
# # 	'Odev110'
# # ]
# screen_names = kafka_stream.map(lambda data: rapidjson.loads(data[1])['screen_name'])
#
# # [
# #	'Odev110',
# # 	'kirillica1957',
# # 	'Odev110'
# # ] => [
# # 	('Odev110', 2),
# #	('kirillica1957', 1)
# # ]
# screen_name__count = screen_names.map(lambda name: (name, 1)).reduceByKey(ssum)
#
# def print_windowed(data_stream, func, time):
# 	windowed_data = data_stream.reduceByKeyAndWindow(func, None, windowDuration=time, slideDuration=time)
# 	windowed_data.transform(lambda rdd: rdd.coalesce(1).sortByKey(ascending=False)).pprint(100)
#
# print_windowed(screen_name__count, ssum, MINUTE)
# print_windowed(screen_name__count, ssum, TEN_MINUTES)
#
# # Start and deinit later
# streaming_context.start()
# streaming_context.awaitTermination()
#
# ```

# %% [markdown]
# **run_spark.sh**
#
# ```bash
# #!/usr/bin/env bash
#
# source /opt/rh/rh-python36/enable
#
# export PYSPARK_PYTHON=python
# export PYSPARK_DRIVER_PYTHON=python
# export PYSPARK_DRIVER_PYTHON_OPTS=""
# spark2-submit --master local[2] $1
# ```

# %% [raw]
# [cloudera@quickstart tweets_tasks]$ ./run_spark.sh tweets_counter_per_timeunit.py
# 18/12/16 06:58:15 INFO spark.SparkContext: Running Spark version 2.3.0.cloudera3
# 18/12/16 06:58:15 INFO spark.SparkContext: Submitted application: UsersTweetsCounter
# ...
# 18/12/16 06:58:17 INFO util.Utils: Extension com.cloudera.spark.lineage.NavigatorAppListener not being initialized.
# -------------------------------------------
# Time: 2018-12-16 06:59:00
# -------------------------------------------
# ('rentvchannel', 1)
# ('proffmed', 1)
# ('mlTerNw9oVRhAl5', 1)
# ('a_weuve', 1)
# ('_kmv_', 1)
# ('SultanIskander', 1)
# ('KZ8JA4mRYTO78Uj', 1)
#
# -------------------------------------------
# Time: 2018-12-16 07:00:00
# -------------------------------------------
# ('wou4ik', 1)
# ('t_Wankan', 1)
# ('oZJnhO5zRr5Fg7c', 1)
# ('nehueviy', 2)
# ('isv_yamal', 1)
# ('gziks1', 1)
# ('eduard_kenig', 1)
# ('asLcqdxsZKLAjJD', 1)
# ('SultanIskander', 1)
# ('Sirius_st', 1)
# ('GirafeMarius', 1)
# ('Dmitriy0709', 1)
# ('DNMotovilov', 1)
#
# -------------------------------------------
# Time: 2018-12-16 07:01:00
# -------------------------------------------
# ('ygodinka', 1)
# ('oCaealqhhAJEfqk', 1)
# ('c1eHA9qsKhbG3Pn', 1)
# ('astahov777', 1)
# ('VLagunov', 1)
# ('SultanIskander', 1)
# ('KZ8JA4mRYTO78Uj', 1)
# ('Evgenia6849', 1)
#
# -------------------------------------------
# Time: 2018-12-16 07:02:00
# -------------------------------------------
# ('vesti_news', 1)
# ('pegass1', 1)
# ('odesit741', 1)
# ('nehueviy', 3)
# ('doctortima', 1)
# ('alexiKulik', 1)
# ('VasiliyRakovich', 1)
# ('VStruncov', 1)
# ('AMilena8891', 1)
#
# -------------------------------------------
# Time: 2018-12-16 07:03:00
# -------------------------------------------
# ('uporotyisterh', 1)
# ('pet19784', 1)
# ('anatoliy156794', 1)
# ('VStruncov', 1)
# ('Tatyana_A2', 1)
# ('SultanIskander', 1)
# ('SO7fHpk6HBBgQUK', 1)
# ('Povar444', 1)
# ('Kag687WN3Wi6SHr', 1)
# ('Honey_in_Blue', 1)
# ('BulentKasapolu2', 1)
# ('AMilena8891', 1)
# ('13tucha1', 1)
#
# -------------------------------------------
# Time: 2018-12-16 07:04:00
# -------------------------------------------
# ('tab2334', 1)
# ('sergey0905', 1)
# ('adgast', 1)
# ('YMGT373', 2)
# ('VStruncov', 1)
# ('PkJY2g8QyTGcH56', 1)
# ('AnnaAlchimie', 1)
# ('Anatoliy_A_Z', 1)
# ('916_71', 1)
#
# -------------------------------------------
# Time: 2018-12-16 07:05:00
# -------------------------------------------
# ('vesti_news', 1)
# ('slav_sh', 1)
# ('pawelwah', 1)
# ('ntvru', 1)
# ('kryzhanskyi', 1)
# ('galla4512', 1)
# ('dmitrij7', 1)
# ('denisvxbk', 1)
# ('YMGT373', 1)
# ('SEWEROKs', 1)
# ('Mr_AMV', 1)
# ('Egorwolfen', 1)
# ('DyakonovaLyubov', 1)
#
# -------------------------------------------
# Time: 2018-12-16 07:06:00
# -------------------------------------------
# ('ramil_b_80', 1)
# ('kryzhanskyi', 1)
# ('kirasir61', 2)
# ('goreshek', 1)
# ('friendlybus', 1)
# ('fedyusha', 1)
# ('eqvival', 1)
# ('Traveller_ru', 1)
# ('TikhonovVal', 1)
# ('SMI_TASS', 1)
# ('Lebirdushka', 1)
# ('Gjhecmz', 1)
# ('GalSockolowa', 1)
# ('13tucha1', 1)
#
# -------------------------------------------
# Time: 2018-12-16 07:07:00
# -------------------------------------------
# ('ntvru', 1)
# ('kryzhanskyi', 1)
# ('interfax_news', 1)
# ('gotovceva', 1)
# ('goreshek', 1)
# ('VLagunov', 1)
# ('UkrSlavemarket', 1)
# ('Szaj4enko', 1)
# ('SultanIskander', 2)
# ('Sasha_Zatonsky', 1)
# ('SEWEROKs', 1)
# ('ProstoNatasha77', 1)
# ('PkJY2g8QyTGcH56', 1)
# ('NekuHatsumi', 1)
# ('8127682', 1)
# ('47Angelina', 1)
#
# -------------------------------------------
# Time: 2018-12-16 07:08:00
# -------------------------------------------
# ('zharaleksan', 1)
# ('kozenna', 1)
# ('goreshek', 1)
# ('eqvival', 1)
# ('climanseur', 1)
# ('VOROBEEY', 1)
# ('VLagunov', 1)
# ('SantaNikol', 1)
# ('RuslanLutcenko', 1)
# ('Eleech38', 1)
# ('46Ieliena', 1)
# ('1BMlo42WfteoBF7', 1)
#
# -------------------------------------------
# Time: 2018-12-16 07:08:00
# -------------------------------------------
# ('zharaleksan', 1)
# ('ygodinka', 1)
# ('wou4ik', 1)
# ('vesti_news', 2)
# ('uporotyisterh', 1)
# ('tab2334', 1)
# ('t_Wankan', 1)
# ('slav_sh', 1)
# ('sergey0905', 1)
# ('rentvchannel', 1)
# ('ramil_b_80', 1)
# ('proffmed', 1)
# ('pet19784', 1)
# ('pegass1', 1)
# ('pawelwah', 1)
# ('odesit741', 1)
# ('oZJnhO5zRr5Fg7c', 1)
# ('oCaealqhhAJEfqk', 1)
# ('ntvru', 2)
# ('nehueviy', 5)
# ('mlTerNw9oVRhAl5', 1)
# ('kryzhanskyi', 3)
# ('kozenna', 1)
# ('kirasir61', 2)
# ('isv_yamal', 1)
# ('interfax_news', 1)
# ('gziks1', 1)
# ('gotovceva', 1)
# ('goreshek', 3)
# ('galla4512', 1)
# ('friendlybus', 1)
# ('fedyusha', 1)
# ('eqvival', 2)
# ('eduard_kenig', 1)
# ('doctortima', 1)
# ('dmitrij7', 1)
# ('denisvxbk', 1)
# ('climanseur', 1)
# ('c1eHA9qsKhbG3Pn', 1)
# ('astahov777', 1)
# ('asLcqdxsZKLAjJD', 1)
# ('anatoliy156794', 1)
# ('alexiKulik', 1)
# ('adgast', 1)
# ('a_weuve', 1)
# ('_kmv_', 1)
# ('YMGT373', 3)
# ('VasiliyRakovich', 1)
# ('VStruncov', 3)
# ('VOROBEEY', 1)
# ('VLagunov', 3)
# ('UkrSlavemarket', 1)
# ('Traveller_ru', 1)
# ('TikhonovVal', 1)
# ('Tatyana_A2', 1)
# ('Szaj4enko', 1)
# ('SultanIskander', 6)
# ('Sirius_st', 1)
# ('Sasha_Zatonsky', 1)
# ('SantaNikol', 1)
# ('SO7fHpk6HBBgQUK', 1)
# ('SMI_TASS', 1)
# ('SEWEROKs', 2)
# ('RuslanLutcenko', 1)
# ('ProstoNatasha77', 1)
# ('Povar444', 1)
# ('PkJY2g8QyTGcH56', 2)
# ('NekuHatsumi', 1)
# ('Mr_AMV', 1)
# ('Lebirdushka', 1)
# ('Kag687WN3Wi6SHr', 1)
# ('KZ8JA4mRYTO78Uj', 2)
# ('Honey_in_Blue', 1)
# ('Gjhecmz', 1)
# ('GirafeMarius', 1)
# ('GalSockolowa', 1)
# ('Evgenia6849', 1)
# ('Eleech38', 1)
# ('Egorwolfen', 1)
# ('DyakonovaLyubov', 1)
# ('Dmitriy0709', 1)
# ('DNMotovilov', 1)
# ('BulentKasapolu2', 1)
# ('AnnaAlchimie', 1)
# ('Anatoliy_A_Z', 1)
# ('AMilena8891', 2)
# ('916_71', 1)
# ('8127682', 1)
# ('47Angelina', 1)
# ('46Ieliena', 1)
# ('1BMlo42WfteoBF7', 1)
# ('13tucha1', 2)

# %% [markdown]
# Проверим подсчет твитов за первую и четвертую минуты.
#
# **Первая минута**
# ```text
# 2018-12-16 06:58:23,198 [INFO] tweets_producer: Start tweets receiving...
# 2018-12-16 06:58:26,898 [INFO] tweets_producer: Received 1 tweet from @SultanIskander[999348547802853378]
# 2018-12-16 06:58:29,764 [INFO] tweets_producer: Received 1 tweet from @mlTerNw9oVRhAl5[3134768049]
# 2018-12-16 06:58:33,962 [INFO] tweets_producer: Received 1 tweet from @a_weuve[4385767653]
# 2018-12-16 06:58:34,987 [INFO] tweets_producer: Received 1 tweet from @rentvchannel[200036850]
# 2018-12-16 06:58:35,909 [INFO] tweets_producer: Received 1 tweet from @_kmv_[161254913]
# 2018-12-16 06:58:52,534 [INFO] tweets_producer: Received 1 tweet from @proffmed[849698890173612032]
# 2018-12-16 06:58:52,907 [INFO] tweets_producer: Received 1 tweet from @KZ8JA4mRYTO78Uj[1071064400340140033]
# ```
# ```text
# -------------------------------------------
# Time: 2018-12-16 06:59:00
# -------------------------------------------
# ('rentvchannel', 1)
# ('proffmed', 1)
# ('mlTerNw9oVRhAl5', 1)
# ('a_weuve', 1)
# ('_kmv_', 1)
# ('SultanIskander', 1)
# ('KZ8JA4mRYTO78Uj', 1)
# ```
#
# **Четвертая минута**
# ```text
# 2018-12-16 07:01:07,566 [INFO] tweets_producer: Received 1 tweet from @nehueviy[2608064537]         <-- 1
# 2018-12-16 07:01:13,932 [INFO] tweets_producer: Received 1 tweet from @doctortima[473824335]
# 2018-12-16 07:01:19,341 [INFO] tweets_producer: Received 1 tweet from @VasiliyRakovich[1340003623]
# 2018-12-16 07:01:20,811 [INFO] tweets_producer: Received 1 tweet from @nehueviy[2608064537]         <-- 2
# 2018-12-16 07:01:27,225 [INFO] tweets_producer: Received 1 tweet from @vesti_news[72525490]
# 2018-12-16 07:01:33,154 [INFO] tweets_producer: Received 1 tweet from @nehueviy[2608064537]         <-- 3
# 2018-12-16 07:01:45,351 [INFO] tweets_producer: Received 1 tweet from @pegass1[209599139]
# 2018-12-16 07:01:47,194 [INFO] tweets_producer: Received 1 tweet from @odesit741[2513730044]
# 2018-12-16 07:01:48,731 [INFO] tweets_producer: Received 1 tweet from @VStruncov[335556970]
# 2018-12-16 07:01:52,109 [INFO] tweets_producer: Received 1 tweet from @alexiKulik[881746967042437121]
# 2018-12-16 07:01:53,338 [INFO] tweets_producer: Received 1 tweet from @AMilena8891[453810289]
# ```
# ```text
# -------------------------------------------
# Time: 2018-12-16 07:02:00
# -------------------------------------------
# ('vesti_news', 1)
# ('pegass1', 1)
# ('odesit741', 1)
# ('nehueviy', 3)       <-- 3
# ('doctortima', 1)
# ('alexiKulik', 1)
# ('VasiliyRakovich', 1)
# ('VStruncov', 1)
# ('AMilena8891', 1)
# ```
#
# Для проверки подсчета твитов за 10 минут напишем скрипт, работающий с выводом **tweets_producer.py**.
#
# **producer_counter.py**
# ```python
# #!/usr/local/bin/python3.6
# import re
# import sys
#
# screen_name_pattern = re.compile(r'@(.*)\[')
#
#
# def main():
# 	screen_names = {}
#
# 	# 2018-12-16 07:01:53,338 [INFO] tweets_producer: Received 1 tweet from @AMilena8891[453810289]
# 	for line in sys.stdin:
# 		if 'tweet from' not in line:
# 			continue
# 		line = line.rstrip()
#
# 		name = re.search(screen_name_pattern, line)
# 		if name:
# 			name = name.group(1)
# 		else:
# 			print(f'Screen name was not found in "{line}"')
# 			continue
#
# 		screen_names[name] = screen_names.get(name, 0) + 1
#
# 	print(f'\n'.join(
# 		map(str, reversed(sorted(screen_names.items(), key=lambda item: item[0])))
# 	))
#
#
# if __name__ == '__main__':
# 	main()
# ```
#
# Сверим подсчет твитов на основе лога **tweets_producer.py** и на основе лога **tweets_counter_per_timeunit.py** (Spark Streaming).

# %% [markdown]
# <table>
#     <tr>
#         <td>
# <br><br>
# $ cat producer.out | ./producer_checker.py<br>
# ('zharaleksan', 1)<br>
# ('ygodinka', 1)<br>
# ('wou4ik', 1)<br>
# ('vesti_news', 2)<br>
# ('uporotyisterh', 1)<br>
# ('tab2334', 1)<br>
# ('t_Wankan', 1)<br>
# ('slav_sh', 1)<br>
# ('sergey0905', 1)<br>
# ('rentvchannel', 1)<br>
# ('ramil_b_80', 1)<br>
# ('proffmed', 1)<br>
# ('pet19784', 1)<br>
# ('pegass1', 1)<br>
# ('pawelwah', 1)<br>
# ('odesit741', 1)<br>
# ('oZJnhO5zRr5Fg7c', 1)<br>
# ('oCaealqhhAJEfqk', 1)<br>
# ('ntvru', 2)<br>
# ('nehueviy', 5)<br>
# ('mlTerNw9oVRhAl5', 1)<br>
# ('kryzhanskyi', 3)<br>
# ('kozenna', 1)<br>
# ('kirasir61', 2)<br>
# ('isv_yamal', 1)<br>
# ('interfax_news', 1)<br>
# ('gziks1', 1)<br>
# ('gotovceva', 1)<br>
# ('goreshek', 3)<br>
# ('galla4512', 1)<br>
# ('friendlybus', 1)<br>
# ('fedyusha', 1)<br>
# ('eqvival', 2)<br>
# ('eduard_kenig', 1)<br>
# ('doctortima', 1)<br>
# ('dmitrij7', 1)<br>
# ('denisvxbk', 1)<br>
# ('climanseur', 1)<br>
# ('c1eHA9qsKhbG3Pn', 1)<br>
# ('astahov777', 1)<br>
# ('asLcqdxsZKLAjJD', 1)<br>
# ('anatoliy156794', 1)<br>
# ('alexiKulik', 1)<br>
# ('adgast', 1)<br>
# ('a_weuve', 1)<br>
# ('_kmv_', 1)<br>
# ('YMGT373', 3)<br>
# ('VasiliyRakovich', 1)<br>
# ('VStruncov', 3)<br>
# ('VOROBEEY', 1)<br>
# ('VLagunov', 3)<br>
# ('UkrSlavemarket', 1)<br>
# ('Traveller_ru', 1)<br>
# ('TikhonovVal', 1)<br>
# ('Tatyana_A2', 1)<br>
# ('Szaj4enko', 1)<br>
# ('SultanIskander', 6)<br>
# ('Sirius_st', 1)<br>
# ('Sasha_Zatonsky', 1)<br>
# ('SantaNikol', 1)<br>
# ('SO7fHpk6HBBgQUK', 1)<br>
# ('SMI_TASS', 1)<br>
# ('SEWEROKs', 2)<br>
# ('RuslanLutcenko', 1)<br>
# ('ProstoNatasha77', 1)<br>
# ('Povar444', 1)<br>
# ('PkJY2g8QyTGcH56', 2)<br>
# ('NekuHatsumi', 1)<br>
# ('Mr_AMV', 1)<br>
# ('Lebirdushka', 1)<br>
# ('Kag687WN3Wi6SHr', 1)<br>
# ('KZ8JA4mRYTO78Uj', 2)<br>
# ('Honey_in_Blue', 1)<br>
# ('Gjhecmz', 1)<br>
# ('GirafeMarius', 1)<br>
# ('GalSockolowa', 1)<br>
# ('Evgenia6849', 1)<br>
# ('Eleech38', 1)<br>
# ('Egorwolfen', 1)<br>
# ('DyakonovaLyubov', 1)<br>
# ('Dmitriy0709', 1)<br>
# ('DNMotovilov', 1)<br>
# ('BulentKasapolu2', 1)<br>
# ('AnnaAlchimie', 1)<br>
# ('Anatoliy_A_Z', 1)<br>
# ('AMilena8891', 2)<br>
# ('916_71', 1)<br>
# ('8127682', 1)<br>
# ('47Angelina', 1)<br>
# ('46Ieliena', 1)<br>
# ('1BMlo42WfteoBF7', 1)<br>
# ('13tucha1', 2)<br>
#         </td>
#         <td>
# -------------------------------------------<br>
# Time: 2018-12-16 07:08:00<br>
# -------------------------------------------<br>
# ('zharaleksan', 1)<br>
# ('ygodinka', 1)<br>
# ('wou4ik', 1)<br>
# ('vesti_news', 2)<br>
# ('uporotyisterh', 1)<br>
# ('tab2334', 1)<br>
# ('t_Wankan', 1)<br>
# ('slav_sh', 1)<br>
# ('sergey0905', 1)<br>
# ('rentvchannel', 1)<br>
# ('ramil_b_80', 1)<br>
# ('proffmed', 1)<br>
# ('pet19784', 1)<br>
# ('pegass1', 1)<br>
# ('pawelwah', 1)<br>
# ('odesit741', 1)<br>
# ('oZJnhO5zRr5Fg7c', 1)<br>
# ('oCaealqhhAJEfqk', 1)<br>
# ('ntvru', 2)<br>
# ('nehueviy', 5)<br>
# ('mlTerNw9oVRhAl5', 1)<br>
# ('kryzhanskyi', 3)<br>
# ('kozenna', 1)<br>
# ('kirasir61', 2)<br>
# ('isv_yamal', 1)<br>
# ('interfax_news', 1)<br>
# ('gziks1', 1)<br>
# ('gotovceva', 1)<br>
# ('goreshek', 3)<br>
# ('galla4512', 1)<br>
# ('friendlybus', 1)<br>
# ('fedyusha', 1)<br>
# ('eqvival', 2)<br>
# ('eduard_kenig', 1)<br>
# ('doctortima', 1)<br>
# ('dmitrij7', 1)<br>
# ('denisvxbk', 1)<br>
# ('climanseur', 1)<br>
# ('c1eHA9qsKhbG3Pn', 1)<br>
# ('astahov777', 1)<br>
# ('asLcqdxsZKLAjJD', 1)<br>
# ('anatoliy156794', 1)<br>
# ('alexiKulik', 1)<br>
# ('adgast', 1)<br>
# ('a_weuve', 1)<br>
# ('_kmv_', 1)<br>
# ('YMGT373', 3)<br>
# ('VasiliyRakovich', 1)<br>
# ('VStruncov', 3)<br>
# ('VOROBEEY', 1)<br>
# ('VLagunov', 3)<br>
# ('UkrSlavemarket', 1)<br>
# ('Traveller_ru', 1)<br>
# ('TikhonovVal', 1)<br>
# ('Tatyana_A2', 1)<br>
# ('Szaj4enko', 1)<br>
# ('SultanIskander', 6)<br>
# ('Sirius_st', 1)<br>
# ('Sasha_Zatonsky', 1)<br>
# ('SantaNikol', 1)<br>
# ('SO7fHpk6HBBgQUK', 1)<br>
# ('SMI_TASS', 1)<br>
# ('SEWEROKs', 2)<br>
# ('RuslanLutcenko', 1)<br>
# ('ProstoNatasha77', 1)<br>
# ('Povar444', 1)<br>
# ('PkJY2g8QyTGcH56', 2)<br>
# ('NekuHatsumi', 1)<br>
# ('Mr_AMV', 1)<br>
# ('Lebirdushka', 1)<br>
# ('Kag687WN3Wi6SHr', 1)<br>
# ('KZ8JA4mRYTO78Uj', 2)<br>
# ('Honey_in_Blue', 1)<br>
# ('Gjhecmz', 1)<br>
# ('GirafeMarius', 1)<br>
# ('GalSockolowa', 1)<br>
# ('Evgenia6849', 1)<br>
# ('Eleech38', 1)<br>
# ('Egorwolfen', 1)<br>
# ('DyakonovaLyubov', 1)<br>
# ('Dmitriy0709', 1)<br>
# ('DNMotovilov', 1)<br>
# ('BulentKasapolu2', 1)<br>
# ('AnnaAlchimie', 1)<br>
# ('Anatoliy_A_Z', 1)<br>
# ('AMilena8891', 2)<br>
# ('916_71', 1)<br>
# ('8127682', 1)<br>
# ('47Angelina', 1)<br>
# ('46Ieliena', 1)<br>
# ('1BMlo42WfteoBF7', 1)<br>
# ('13tucha1', 2)<br>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# Таким образом, программа верно выводит количество твитов пользователя **за очередную минуту** и **за очередные 10 минут**,
#
# при этом подсчет выполняется **каждые 30 секунд**.
